# %% [markdown]
# # Курсовой проект для курса "Python для Data Science"

# %% [markdown]
# Задание:
# Используя данные из обучающего датасета (train.csv), построить модель для предсказания цен на недвижимость (квартиры).
# С помощью полученной модели, предсказать цены для квартир из тестового датасета (test.csv).

# %% [markdown]
# Материалы к проекту (файлы):
# train.csv
# test.csv

# %% [markdown]
# Целевая переменная:
# Price

# %% [markdown]
# Метрика качества:
# R2 - коэффициент детерминации (sklearn.metrics.r2_score)

# %% [markdown]
# ### Импорты

# %%
import numpy as np
import pandas as pd
import pickle

import matplotlib
import matplotlib.image as img
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde
from scipy.stats import norm
import random
import warnings
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import LogisticRegression


from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor


from sklearn.metrics import r2_score as r2, mean_absolute_error as mae, mean_squared_error as mse
from sklearn.model_selection import KFold, GridSearchCV
from sklearn import preprocessing
from sklearn import utils

warnings.filterwarnings('ignore')
# %matplotlib inline
# svg не подключаем, так как система не справляется с таким болшим количеством векторной графики.

# %% [markdown]
# ### Функции

# %%
def evaluate_preds(true_values, pred_values):
    print("R2:\t" + str(round(r2(true_values, pred_values), 3)) + "\n" +
          "MAE:\t" + str(round(mae(true_values, pred_values), 3)) + "\n" +
          "MSE:\t" + str(round(mse(true_values, pred_values), 3)))
    
    plt.figure(figsize=(10,10))
    
    sns.scatterplot(x=pred_values, y=true_values)
    
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('True vs Predicted values')
    plt.show()

# %%
def distribution_overview(dFrame, attribute, title, scale=0.028, bns=None):
    mean = round(dFrame[attribute].mean(), 2)
    median = dFrame[attribute].median()
    mode = dFrame[attribute].mode()[0]
    min = dFrame[attribute].min()
    max = dFrame[attribute].max()
    q25 = dFrame[attribute].quantile(0.25)
    q75 = dFrame[attribute].quantile(0.95)
    q01 = dFrame[attribute].quantile(0.005)
    q99 = dFrame[attribute].quantile(0.995)

    plt.figure(figsize = (12, 8))
    sns.distplot(dFrame.loc[dFrame[attribute].notnull(), attribute], bins=bns)

    y = np.linspace(0, scale, 100)
    plt.plot([mean]*100, y, label='mean', linestyle=':', linewidth=4)
    plt.plot([median]*100, y, label='median', linestyle='--', linewidth=4)
    plt.plot([mode]*100, y, label='mode', linestyle='-.', linewidth=4)

    plt.title(title)
    plt.legend()

    print(f'min: {min}, quantile 0,01: {q01}, quantile 0,25: {q25}, mean: {mean}, median: {median}, mode: {mode}, quantile 0,75: {q75}, quantile 0,99: {q99}, max: {max}')

    plt.show()

# %% [markdown]
# ### Описание датасета

# %% [markdown]
# * **Id** - идентификационный номер квартиры
# * **DistrictId** - идентификационный номер района
# * **Rooms** - количество комнат
# * **Square** - площадь
# * **LifeSquare** - жилая площадь
# * **KitchenSquare** - площадь кухни
# * **Floor** - этаж
# * **HouseFloor** - количество этажей в доме
# * **HouseYear** - год постройки дома
# * **Ecology_1, Ecology_2, Ecology_3** - экологические показатели местности
# * **Social_1, Social_2, Social_3** - социальные показатели местности
# * **Healthcare_1, Helthcare_2** - показатели местности, связанные с охраной здоровья
# * **Shops_1, Shops_2** - показатели, связанные с наличием магазинов, торговых центров
# * **Price** - цена квартиры

# %% [markdown]
# ### Файло

# %%
TRAIN_DATASET_PATH = 'train.csv'

# %%
TEST_DATASET_PATH = 'test.csv'

# %%
DF_TRAIN_DATASET_PATH = 'df_train.csv'

# %%
DF_TEST_DATASET_PATH = 'df_test.csv'

# %%
DF_TEST_RESULT_DATASET_PATH = 'df_test_res.csv'

# %%
TRAIN_DATASET_PATH_ADD = 'df_add.csv'

# %%
TEST_DATASET_PATH_ADD = 'df_test_add.csv'

# %% [markdown]
# ### Загрузка тренировочного набора

# %%
df = pd.read_csv(TRAIN_DATASET_PATH)
df.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %% [markdown]
# ### Приведение типов данных

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
df.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# Price            float64
# dtype: object

# %% [markdown]
# Количество комнат должно быть целым числом.

# %%
df['Rooms'].dtype
# Out:
# dtype('float64')

# %%
df['Rooms'] = df['Rooms'].astype('int64')

# %%
df['Rooms'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Количество этажей целочисленное значение.

# %%
df['HouseFloor'].dtype
# Out:
# dtype('float64')

# %%
df['HouseFloor'] = df['HouseFloor'].astype('int64')

# %%
df['HouseFloor'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Площадь кухни по факту есть целочисленное значение, что ни есть целочисленное значение, то есть выброс.

# %%
df['KitchenSquare'].dtype
# Out:
# dtype('float64')

# %%
df['KitchenSquare'] = df['KitchenSquare'].astype('int64')

# %%
df['KitchenSquare'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Статистика

# %%
df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000   5202.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1142.904460      1.319500
# std       17.532614   4006.799803     23.831875   1021.517264      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000    900.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1548.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %% [markdown]
# ### Обзор количественных переменных

# %%
df_num_features = df.select_dtypes(include=['float64', 'int64'])
df_num_features.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35      2  47.981561   29.442751              6      7
# 1  15053          41      3  65.683640   40.049543              8      7
# 2   4765          53      2  44.947953   29.197612              0      8
# 3   5809          58      2  53.352981   52.731512              9      8
# 4  10783          99      1  39.649192   23.776169              7     11
#
#    HouseFloor  HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# 0           9       1969   0.089040        33      7976         5
# 1           9       1978   0.000070        46     10309         1
# 2          12       1968   0.049637        34      7759         0
# 3          17       1977   0.437885        23      5735         3
# 4          12       1976   0.012339        35      5776         1
#
#    Healthcare_1  Helthcare_2  Shops_1          Price
# 0           NaN            0       11  184966.930730
# 1         240.0            1       16  300009.450063
# 2         229.0            1        3  220925.908524
# 3        1084.0            0        5  175616.227217
# 4        2078.0            2        4  150226.531644

# %% [markdown]
# ### Обзор номинативных переменных

# %%
df_obj_features = df.select_dtypes(include='object')
df_obj_features.head()
# Out:
#   Ecology_2 Ecology_3 Shops_2
# 0         B         B       B
# 1         B         B       B
# 2         B         B       B
# 3         B         B       B
# 4         B         B       B

# %%
df['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %%
df['Ecology_3'].value_counts()
# Out:
# B    9725
# A     275
# Name: Ecology_3, dtype: int64

# %%
df['Shops_2'].value_counts()
# Out:
# B    9175
# A     825
# Name: Shops_2, dtype: int64

# %% [markdown]
# ### Обработка пропусков

# %%
len(df) - df.count()
# Out:
# Id                  0
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       2113
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     4798
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# Price               0
# dtype: int64

# %% [markdown]
# **LifeSquare**

# %% [markdown]
# Поскольку пустых значений слишком много, то рассмотрим их в зависимости от срезов по количеству комнат и по годам и заполним значениями медианы по этим срезам.

# %%
df['Rooms'][df['LifeSquare'].isnull()].value_counts()
# Out:
# 1    878
# 2    828
# 3    393
# 4      9
# 0      3
# 5      2
# Name: Rooms, dtype: int64

# %%
df['HouseYear'][df['LifeSquare'].isnull()].value_counts()
# Out:
# 1977    1857
# 2016      64
# 2017      62
# 2015      57
# 2014      42
# 2018      20
# 2019       6
# 2013       4
# 2012       1
# Name: HouseYear, dtype: int64

# %%
for room in df['Rooms'][df['LifeSquare'].isnull()].unique():
    for year in df['HouseYear'][df['LifeSquare'].isnull()].unique():
        for floor in df['HouseFloor'][df['LifeSquare'].isnull()].unique():
            df.loc[df['LifeSquare'].isnull() & (df['Rooms'] == room) & (df['HouseYear'] == year) & (df['HouseFloor'] == floor), 'LifeSquare'] = df['LifeSquare'][df['LifeSquare'].notnull() & (df['Rooms'] == room) & (df['HouseYear'] == year) & (df['HouseFloor'] == floor)].median()

# %%
for room in df['Rooms'][df['LifeSquare'].isnull()].unique():
    for year in df['HouseYear'][df['LifeSquare'].isnull()].unique():
        df.loc[df['LifeSquare'].isnull() & (df['Rooms'] == room) & (df['HouseYear'] == year), 'LifeSquare'] = df['LifeSquare'][df['LifeSquare'].notnull() & (df['Rooms'] == room) & (df['HouseYear'] == year)].median()

# %%
df.loc[df['LifeSquare'].isnull(), 'LifeSquare'] = df['LifeSquare'][df['LifeSquare'].notnull()].median()

# %% [markdown]
# **Healthcare_1**

# %% [markdown]
# "Раскидаем" пустые значения по имеющимся классам значений

# %% [markdown]
# Получим уникальные значения из выборки

# %%
values = list(df.loc[df['Healthcare_1'].notnull(), 'Healthcare_1'].unique())

# %%
values = sorted(values)

# %%
length = len(values)

# %%
length
# Out:
# 79

# %%
values[:5]
# Out:
# [0.0, 30.0, 32.0, 35.0, 46.0]

# %%
values[length - 5:]
# Out:
# [4087.0, 4129.0, 4508.0, 4702.0, 4849.0]

# %%
b = df.loc[df['Healthcare_1'].isnull()]

# %%
for id in b['Id']:
    df.loc[df['Id'] == id, 'Healthcare_1'] = values[random.randint(0, length - 1)]

# %% [markdown]
# **Ecology_2**

# %%
df['Ecology_2'].mode()[0]
# Out:
# 'B'

# %%
df.replace({'Ecology_2': {'-':df['Ecology_2'].mode()[0]}}, inplace=True)

# %%
df['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %% [markdown]
# **Ecology_3**

# %%
df['Ecology_3'].mode()[0]
# Out:
# 'B'

# %%
df.replace({'Ecology_3': {'-':df['Ecology_3'].mode()[0]}}, inplace=True)

# %%
df['Ecology_3'].value_counts()
# Out:
# B    9725
# A     275
# Name: Ecology_3, dtype: int64

# %% [markdown]
# **Shops_2**

# %%
df['Shops_2'].mode()[0]
# Out:
# 'B'

# %%
df.replace({'Shops_2': {'-':df['Shops_2'].mode()[0]}}, inplace=True)

# %%
df['Shops_2'].value_counts()
# Out:
# B    9175
# A     825
# Name: Shops_2, dtype: int64

# %% [markdown]
# ### Обработка выбросов

# %%
df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.890500     56.315775     39.495823
# std     4859.01902     43.587592      0.839512     21.058732     77.151686
# min        0.00000      0.000000      0.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     23.811124
# 50%     8394.50000     36.000000      2.000000     52.513310     35.704183
# 75%    12592.50000     75.000000      2.000000     65.900625     47.015242
# max    16798.00000    209.000000     19.000000    641.065193   7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1249.989300      1.319500
# std       17.532614   4006.799803     23.831875   1117.855174      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000   1015.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1894.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %% [markdown]
# Почти все признаки имеют выбросы.

# %%
df.head(10)
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35      2  47.981561   29.442751              6      7
# 1  15053          41      3  65.683640   40.049543              8      7
# 2   4765          53      2  44.947953   29.197612              0      8
# 3   5809          58      2  53.352981   52.731512              9      8
# 4  10783          99      1  39.649192   23.776169              7     11
# 5  12915          59      3  80.384479   46.683720             12      5
# 6  14549         154      2  62.254114   37.160377              7      3
# 7  11993          74      2  80.312926   37.038420              0     14
# 8   5172           1      2  64.511437   61.478074              1      9
# 9   8649          23      1  46.461409   18.915552              8     13
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0           9       1969   0.089040         B         B        33      7976
# 1           9       1978   0.000070         B         B        46     10309
# 2          12       1968   0.049637         B         B        34      7759
# 3          17       1977   0.437885         B         B        23      5735
# 4          12       1976   0.012339         B         B        35      5776
# 5          17       2011   0.309479         B         B        35      7715
# 6           5       1960   0.460556         B         B        20      4386
# 7           0       1977   0.075779         B         B         6      1437
# 8          17       1977   0.007122         B         B         1       264
# 9          17       2014   0.075779         B         B         6      1437
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5         370.0            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644
# 5         4         990.0            0        6       B  215898.447742
# 6        14        1308.0            1        5       B  296021.204377
# 7         3        2715.0            0        2       B  221244.156664
# 8         0         645.0            0        1       B  229102.795999
# 9         3        1548.0            0        2       B   95380.220993

# %%
df.tail(10)
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9990  15233           1      3   57.373889   39.688445              5      2
# 9991  11553           3      3  101.622794   51.628780             12     18
# 9992  14333         150      3   78.249637   49.385096             10      5
# 9993     48          13      3   80.631333   48.899083             10     11
# 9994   4158          23      2   64.864198   61.478074              1     17
# 9995     77          32      2   50.401785   30.476203              5      6
# 9996   6159          18      1   41.521546   20.539216              9     13
# 9997   5123          27      1   47.939008   48.696782              1     12
# 9998   5400          75      2   43.602562   33.840147              8      1
# 9999   6306         128      1   38.666645   21.157874              8      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9990           5       1962   0.036270         B         B         6
# 9991          17       2000   0.265089         B         B        37
# 9992          16       1976   0.300323         B         B        52
# 9993          14       1999   0.090799         B         B        74
# 9994          17       1977   0.075779         B         B         6
# 9995           5       1968   0.135650         B         B        46
# 9996          13       2000   0.000000         B         B        30
# 9997          16       2015   0.072158         B         B         2
# 9998           5       1961   0.307467         B         A        30
# 9999          17       1990   0.000000         B         B        27
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9990      1318         1         200.0            1        1       B
# 9991      5288         0        1937.0            3        2       B
# 9992     10311         6        1994.0            1        9       B
# 9993     19083         2        4087.0            5       15       B
# 9994      1437         3        2301.0            0        2       B
# 9995      7960         6         350.0            3       11       B
# 9996      5562         0         810.0            0        5       A
# 9997       629         1         900.0            0        0       A
# 9998      5048         9         325.0            2        5       B
# 9999      4798         0          30.0            2        8       B
#
#               Price
# 9990  163807.542987
# 9991  212883.501504
# 9992  342418.758888
# 9993  350684.628560
# 9994  171323.515653
# 9995  196684.316040
# 9996  189050.289571
# 9997  159143.805370
# 9998  181595.339808
# 9999  218714.077615

# %% [markdown]
# **HouseYear**

# %%
df.sort_values(by="HouseYear", inplace=True)

# %%
df['HouseYear'].value_counts().head(11)
# Out:
# 1977    2652
# 2017     308
# 2016     305
# 2015     299
# 2014     210
# 1970     194
# 1969     190
# 1972     178
# 1971     177
# 2018     175
# 1974     169
# Name: HouseYear, dtype: int64

# %%
df['HouseYear'].head()
# Out:
# 9317    1910
# 2656    1912
# 5111    1912
# 910     1914
# 7611    1916
# Name: HouseYear, dtype: int64

# %%
df['HouseYear'].tail()
# Out:
# 7076        2020
# 5701        2020
# 1499        2020
# 4189        4968
# 1497    20052011
# Name: HouseYear, dtype: int64

# %%
df.replace({'HouseYear': {4968:1968}}, inplace=True)

# %%
df.replace({'HouseYear': {20052011:2005}}, inplace=True)

# %% [markdown]
# **Rooms**

# %%
df.sort_values(by="Rooms", inplace=True)

# %%
df['Rooms'].unique()
# Out:
# array([ 0,  1,  2,  3,  4,  5,  6, 10, 19], dtype=int64)

# %%
df.loc[df['Rooms'].notnull(), 'Rooms'].value_counts()
# Out:
# 2     3880
# 1     3705
# 3     2235
# 4      150
# 5       18
# 0        8
# 10       2
# 6        1
# 19       1
# Name: Rooms, dtype: int64

# %% [markdown]
# Убираем 0, 10, 6, 19.

# %%
df.loc[df['Rooms'] == 0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 8834   9443          27      0   87.762616   85.125471              0      5
# 1397  12638          27      0  138.427694  136.215499              0      4
# 3911    770          28      0   49.483501   35.704183              0     16
# 6149   3159          88      0   38.697117   19.345131              9      9
# 1981   7917          27      0  212.932361  211.231125              0      2
# 2269   7317          27      0   41.790881    0.873147              0     13
# 4366    456           6      0   81.491446    0.873147              0      4
# 4853   3224          27      0    2.377248    0.873147              0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 8834          15       1977   0.211401         B         B         9
# 1397           3       2016   0.075424         B         B        11
# 3911           0       2015   0.118537         B         B        30
# 6149          16       1982   0.127376         B         B        43
# 1981           3       2008   0.211401         B         B         9
# 2269           0       1977   0.211401         B         B         9
# 4366           0       1977   0.243205         B         B         5
# 4853           0       1977   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 8834      1892         0          80.0            0        1       B
# 1397      3097         0        2500.0            0        0       B
# 3911      6207         1        1183.0            1        0       B
# 6149      8429         3         900.0            3        9       B
# 1981      1892         0          46.0            0        1       B
# 2269      1892         0        1786.0            0        1       B
# 4366      1564         0         540.0            0        0       B
# 4853       469         0        1815.0            0        0       B
#
#               Price
# 8834  219281.918007
# 1397  268394.744389
# 3911  217009.338463
# 6149  158998.110646
# 1981  302211.260887
# 2269   98129.976788
# 4366  212864.799112
# 4853  126596.941798

# %%
df.loc[(df['Rooms'] == 0.0) & (df['Square'] < 45.0), 'Rooms'] = 1

# %%
df.loc[(df['Rooms'] == 0.0) & df['Square'].between(45.0, 65.0), 'Rooms'] = 2

# %%
df.loc[(df['Rooms'] == 0.0) & df['Square'].between(65.0, 85.0), 'Rooms'] = 3

# %%
df.loc[(df['Rooms'] == 0.0) & df['Square'].between(85.0, 105.0), 'Rooms'] = 4

# %%
df.loc[(df['Rooms'] == 0.0) & (df['Square'] > 106), 'Rooms'] = 5

# %%
df.loc[df['Rooms'] == 6]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2170  14003          99      6  59.414334   38.702244              6      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2170           9       1969   0.033494         B         B        66
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 2170     10573         1        1322.0            3        8       B
#
#               Price
# 2170  229661.964416

# %%
df.loc[df['Id'] == 14003, 'Rooms'] = 2

# %%
df.loc[df['Rooms'] == 10]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 8849  14865           9     10  60.871266   38.420681             10      3
# 377    5927          57     10  59.056975   36.223072             10     22
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 8849           2       1994   0.161532         B         B        25
# 377           22       2002   0.090799         B         B        74
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 8849      5648         1          30.0            2        4       B
# 377      19083         2        1015.0            5       15       B
#
#               Price
# 8849  172329.270863
# 377   317265.323792

# %%
df.loc[df['Rooms'] == 10, 'Rooms'] = 2

# %%
df.loc[df['Rooms'] == 19]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1454  8491           1     19  42.006046   21.779288              7     17
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1454          17       2014   0.007122         B         B         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1454       264         0         176.0            0        1       B
#
#              Price
# 1454  78364.616704

# %%
df.loc[df['Rooms'] == 19, 'Rooms'] = 1

# %% [markdown]
# **HouseFloor**

# %%
df.sort_values(by="HouseFloor", inplace=True)

# %%
df.head()
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 6299  2835          74      1  34.105832   37.976027              0      3
# 5225  2597         169      1  43.257138   37.976027              0      5
# 2102  1539           6      2  55.084228   37.038420              0     12
# 223   4622          27      2  62.153994   36.094352              0      5
# 9199  8755          62      2  79.329878   37.038420              0     17
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6299           0       1977   0.075779         B         B         6
# 5225           0       1977   0.178917         B         B        18
# 2102           0       1977   0.243205         B         B         5
# 223            0       1977   0.072158         B         B         2
# 9199           0       1977   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6299      1437         3        2729.0            0        2       B
# 5225      3594         4         192.0            1        5       B
# 2102      1564         0         540.0            0        0       B
# 223        629         1        1940.0            0        0       A
# 9199       629         1        1894.0            0        0       A
#
#               Price
# 6299  129203.965386
# 5225  226053.135229
# 2102  146456.645948
# 223   194091.992560
# 9199  202549.009085

# %%
df.tail()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2781   1674          76      2   74.344672   41.044132              5     42
# 7728   7453          24      3  126.621358   62.455481             12     22
# 6131  10806           5      1   51.944587   48.709601              1      6
# 8599   9300          74      2   71.747869   74.579809              9      5
# 8854     78          30      2   65.773749   66.811789              1      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2781          48       2016   0.000000         B         B         7
# 7728          48       2011   0.111627         B         B        50
# 6131          99       1977   0.150818         B         B        16
# 8599          99       1977   0.075779         B         B         6
# 8854         117       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 2781      1660        39        1786.0            1        5       B
# 7728     12238         8        1970.0            2        3       B
# 6131      3433         4        2643.0            4        5       B
# 8599      1437         3         800.0            0        2       B
# 8854      6398       141        1046.0            3       23       B
#
#               Price
# 2781  411691.504766
# 7728  179396.521035
# 6131  296127.115515
# 8599  243329.912579
# 8854  207248.370520

# %%
df.loc[df['Id'] == 9300, 'HouseFloor'] = 9

# %%
df.loc[df['Id'] == 10806, 'HouseFloor'] = 9

# %%
df.loc[df['Id'] == 78, 'HouseFloor'] = 17

# %% [markdown]
# **Square**

# %%
df.sort_values(by="Square", inplace=True)

# %%
df.head()
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 6392  14786           1      1  1.136859    4.525736              1      3
# 8283  15744          34      1  1.988943    2.642219              1     21
# 4853   3224          27      1  2.377248    0.873147              0      1
# 1608  10202           6      1  2.596351    4.604943              1      3
# 9294   6782          45      1  2.954309    5.257278              1      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6392           1       1977   0.007122         B         B         1
# 8283           4       1977   0.069753         B         B        53
# 4853           0       1977   0.017647         B         B         2
# 1608          25       2014   0.243205         B         B         5
# 9294           1       1977   0.195781         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6392       264         0        2500.0            0        1       B
# 8283     13670         4        1786.0            1       11       B
# 4853       469         0        1815.0            0        0       B
# 1608      1564         0         540.0            0        0       B
# 9294      5212         6          80.0            3        2       B
#
#               Price
# 6392  181434.825589
# 8283  458378.777006
# 4853  126596.941798
# 1608  137597.601458
# 9294  438005.182323

# %%
df.tail()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1981   7917          27      5  212.932361  211.231125              0      2
# 1982   5548          86      5  275.645284  233.949309             26     12
# 4690   2307         102      1  409.425181  410.639749             10      4
# 4262     28           9      2  604.705972   63.611892              1     17
# 6977  11602          30      2  641.065193  638.163193             10     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1981           3       2008   0.211401         B         B         9
# 1982          37       2011   0.161976         B         A        31
# 4690           4       2016   0.238617         B         B        26
# 4262          18       1977   0.161532         B         B        25
# 6977          19       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1981      1892         0          46.0            0        1       B
# 1982      7010         5        4508.0            3        7       B
# 4690      3889         6         705.0            3        6       B
# 4262      5648         1          30.0            2        4       B
# 6977      6398       141        1046.0            3       23       B
#
#               Price
# 1981  302211.260887
# 1982  455264.882666
# 4690   90470.430830
# 4262  187717.242538
# 6977  133529.681562

# %%
df = df.drop(df[df['Square'] > 250].index)

# %%
df.tail()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7201   3233         129      4  186.692602   87.487080             32      3
# 652    3718          56      3  190.857689  107.376164             19      7
# 8511   4249          23      5  198.930182  123.139863             10      1
# 9910  16568          27      4  200.334539  201.627361             25      1
# 1981   7917          27      5  212.932361  211.231125              0      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 7201           3       2011   0.020741         B         B        24
# 652            3       2007   0.000000         B         B        23
# 8511           2       2011   0.014073         B         B         2
# 9910           2       2013   0.041116         B         B        53
# 1981           3       2008   0.211401         B         B         9
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 7201      5613         5        1340.0            2        5       B
# 652       5067         4         520.0            2        6       B
# 8511       475         0        1020.0            0        0       B
# 9910     14892         4           0.0            1        4       B
# 1981      1892         0          46.0            0        1       B
#
#               Price
# 7201  423443.464367
# 652   338644.075979
# 8511  345665.209100
# 9910  528560.506016
# 1981  302211.260887

# %% [markdown]
# **LifeSquare**

# %%
df.sort_values(by="LifeSquare", inplace=True)

# %%
df.tail()
# Out:
#          Id  DistrictId  Rooms      Square   LifeSquare  KitchenSquare  Floor  \
# 9910  16568          27      4  200.334539   201.627361             25      1
# 1981   7917          27      5  212.932361   211.231125              0      2
# 590   14990          23      2   48.449873   263.542020              5      6
# 8437  15886          85      3   78.059331   461.463614             10     12
# 4328  16550          27      3   81.694417  7480.592129              1      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9910           2       2013   0.041116         B         B        53
# 1981           3       2008   0.211401         B         B         9
# 590            5       1972   0.075779         B         B         6
# 8437          16       1998   0.037178         B         B        52
# 4328          17       2016   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9910     14892         4           0.0            1        4       B
# 1981      1892         0          46.0            0        1       B
# 590       1437         3        1575.0            0        2       B
# 8437     11217         1        2300.0            1        7       B
# 4328       469         0        2078.0            0        0       B
#
#               Price
# 9910  528560.506016
# 1981  302211.260887
# 590   141780.231857
# 8437  394253.299978
# 4328  217357.492366

# %%
df = df.drop(df[df['LifeSquare'] > 250].index)

# %%
df.tail()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 8913   2603          30      3  162.587886  164.526757              0      2
# 3651   5300          30      3  169.509941  170.713651              1      2
# 1641  11055         151      1  174.649522  174.837082             15     10
# 9910  16568          27      4  200.334539  201.627361             25      1
# 1981   7917          27      5  212.932361  211.231125              0      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 8913           3       1977   0.000078         B         B        22
# 3651           2       2018   0.000078         B         B        22
# 1641          12       1958   0.236108         B         B        16
# 9910           2       2013   0.041116         B         B        53
# 1981           3       2008   0.211401         B         B         9
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 8913      6398       141        1046.0            3       23       B
# 3651      6398       141        1046.0            3       23       B
# 1641      3893        27         192.0            3       10       B
# 9910     14892         4           0.0            1        4       B
# 1981      1892         0          46.0            0        1       B
#
#               Price
# 8913  207407.352593
# 3651  200800.673767
# 1641  232766.187698
# 9910  528560.506016
# 1981  302211.260887

# %% [markdown]
# **KitchenSquare**

# %%
df.sort_values(by="KitchenSquare", inplace=True)

# %%
df.tail()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 4651  12552          58      3  116.405693  113.109653            112      3
# 2969   7441          62      3  114.734473  112.589083            112      3
# 9895   2737          27      3  123.430072  125.806981            123      5
# 8584  14679          81      1   32.276663   19.278394           1970      6
# 1064  14656          62      1   47.100719   46.447960           2014      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4651           3       2016   0.437885         B         B        23
# 2969           3       2015   0.072158         B         B         2
# 9895          10       2015   0.017647         B         B         2
# 8584           1       1977   0.006076         B         B        30
# 1064           1       2014   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4651      5735         3        1084.0            0        5       B
# 2969       629         1        1020.0            0        0       A
# 9895       469         0         125.0            0        0       B
# 8584      5285         0         645.0            6        6       B
# 1064       629         1        1036.0            0        0       A
#
#               Price
# 4651  296165.936689
# 2969  315245.521059
# 9895  234194.837047
# 8584  105539.556275
# 1064  108337.484207

# %%
df = df.drop(df[df['KitchenSquare'] > 250].index)

# %%
df.tail()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7088   6569          27      1   38.220258   18.716856             84      4
# 2916  12390          72      3   97.490674   99.323558             96     22
# 4651  12552          58      3  116.405693  113.109653            112      3
# 2969   7441          62      3  114.734473  112.589083            112      3
# 9895   2737          27      3  123.430072  125.806981            123      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 7088          17       2018   0.011654         B         B         4
# 2916          25       2019   0.210473         B         B        11
# 4651           3       2016   0.437885         B         B        23
# 2969           3       2015   0.072158         B         B         2
# 9895          10       2015   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 7088       915         0        4849.0            0        0       B
# 2916      2398         2        1994.0            3        0       B
# 4651      5735         3        1084.0            0        5       B
# 2969       629         1        1020.0            0        0       A
# 9895       469         0         125.0            0        0       B
#
#               Price
# 7088   99079.960518
# 2916  445074.956552
# 4651  296165.936689
# 2969  315245.521059
# 9895  234194.837047

# %% [markdown]
# ### Отбор и построение новых признаков

# %%
df.sort_values(by="Id", inplace=True)

# %%
df.loc[df['Price'].notnull(), 'Square_Price'] = df.loc[df['Price'].notnull(), 'Square'] / df.loc[df['Price'].notnull(), 'Price']

# %%
df = pd.concat([df, pd.get_dummies(df['Ecology_2'], prefix='Ecology_2')], axis=1)

# %%
df = pd.concat([df, pd.get_dummies(df['Ecology_3'], prefix='Ecology_3')], axis=1)

# %%
df = pd.concat([df, pd.get_dummies(df['Shops_2'], prefix='Shops_2')], axis=1)

# %%
# df.drop(['Id'],axis=1,inplace=True)

# %%
df.drop(['Ecology_2'],axis=1,inplace=True)

# %%
df.drop(['Ecology_3'],axis=1,inplace=True)

# %%
df.drop(['Shops_2'],axis=1,inplace=True)

# %%
df.head()
# Out:
#       Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7885   0           0      1  109.144492   84.613939             15      6
# 5549   2           2      1   34.472263   16.069376              5      5
# 4808   5           5      3   57.607965   38.955672              5      3
# 4447   6           6      1   42.466813   40.010160              1     14
# 2684  10           6      3   75.888156   78.324716              1     11
#
#       HouseFloor  HouseYear  Ecology_1  ...  Helthcare_2  Shops_1  \
# 7885          15       2011   0.319809  ...            5        8
# 5549          18       1969   0.000000  ...            2        5
# 4808           9       1974   0.150818  ...            4        5
# 4447          17       2014   0.243205  ...            0        0
# 2684          17       2014   0.243205  ...            0        0
#
#               Price  Square_Price  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 7885  289034.391871      0.000378            0            1            0
# 5549  174548.966339      0.000197            0            1            0
# 4808  258091.883679      0.000223            0            1            0
# 4447  127196.762031      0.000334            0            1            0
# 2684  218500.747041      0.000347            0            1            0
#
#       Ecology_3_B  Shops_2_A  Shops_2_B
# 7885            1          0          1
# 5549            1          0          1
# 4808            1          0          1
# 4447            1          0          1
# 2684            1          0          1
#
# [5 rows x 24 columns]

# %%
train_add = df[:]

# %% [markdown]
# ### Анализ целевой переменной

# %%
plt.figure(figsize = (12, 8))

plt.subplot(121)
df['Price'].hist()
plt.ylabel('Количество квартир по такой цене')
plt.xlabel('Цена')

plt.subplot(122)
sns.kdeplot(df['Price'], shade=True, legend=False)
plt.xlabel('Цена')

plt.suptitle('Распределение цены')
plt.show()

# %% [markdown]
# Почти идеальное нормальное распределение.

# %%
target_mean = round(df['Price'].mean(), 2)
target_median = df['Price'].median()
target_mode = df['Price'].mode()[0]

target_mean, target_median, target_mode
# Out:
# (214148.17, 192302.75194072496, 59174.77802758122)

# %%
plt.figure(figsize = (12, 8))

sns.distplot(df['Price'])

y = np.linspace(0, 0.000005, 100)
plt.plot([target_mean] * 100, y, label='mean', linestyle=':', linewidth=4)
plt.plot([target_median] * 100, y, label='median', linestyle='--', linewidth=4)
plt.plot([target_mode] * 100, y, label='mode', linestyle='-.', linewidth=4)

plt.title('Распределение цены')
plt.legend()
plt.show()

# %% [markdown]
# ### Анализ признаков

# %%
df_num_features = df.select_dtypes(include=['float64', 'int64'])

# %%
df_num_features.hist(figsize=(12,12), bins=20, grid=False);

# %%
# sns.pairplot(df_num_features);

# %%
grid = sns.jointplot(df_num_features['HouseYear'], df_num_features['Square'], kind='reg')
grid.fig.set_figwidth(12)
grid.fig.set_figheight(12)

plt.show()

# %%
plt.figure(figsize = (20,15))

sns.set(font_scale=1.4)
sns.heatmap(df_num_features.corr(), annot=True, linewidths=.5, cmap='GnBu')

plt.title('Корреляционная матрица')
plt.show()

# %%
grid = sns.jointplot(df['Rooms'], df['Price'], kind='kde')
grid.fig.set_figwidth(12)
grid.fig.set_figheight(12)

plt.show()

# %%
grid = sns.jointplot(df['Square'], df['Price'], kind='kde')
grid.fig.set_figwidth(12)
grid.fig.set_figheight(12)

plt.show()

# %%
grid = sns.jointplot(df['Social_1'], df['Price'], kind='kde')
grid.fig.set_figwidth(12)
grid.fig.set_figheight(12)

plt.show()

# %%
grid = sns.jointplot(df['DistrictId'], df['Price'], kind='kde')
grid.fig.set_figwidth(12)
grid.fig.set_figheight(12)

plt.show()

# %%
grid = sns.jointplot(df['Social_1'], df['Social_2'], kind='kde')
grid.fig.set_figwidth(12)
grid.fig.set_figheight(12)

plt.show()

# %% [markdown]
# ### Отбор признаков

# %%
df.columns.tolist()
# Out:
# ['Id',
#  'DistrictId',
#  'Rooms',
#  'Square',
#  'LifeSquare',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Social_1',
#  'Social_2',
#  'Social_3',
#  'Healthcare_1',
#  'Helthcare_2',
#  'Shops_1',
#  'Price',
#  'Square_Price',
#  'Ecology_2_A',
#  'Ecology_2_B',
#  'Ecology_3_A',
#  'Ecology_3_B',
#  'Shops_2_A',
#  'Shops_2_B']

# %%
feature_names = ['DistrictId', 'Rooms', 'Square', 'Square_Price', 'KitchenSquare', 'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Social_1', 'Social_2', 'Social_3', 'Helthcare_2', 'Shops_1', 'Ecology_2_A', 'Ecology_2_B', 'Ecology_3_A', 'Ecology_3_B', 'Shops_2_A', 'Shops_2_B']
target_name = 'Price'

# %%
df = df[feature_names + [target_name]]
df.head()
# Out:
#       DistrictId  Rooms      Square  Square_Price  KitchenSquare  Floor  \
# 7885           0      1  109.144492      0.000378             15      6
# 5549           2      1   34.472263      0.000197              5      5
# 4808           5      3   57.607965      0.000223              5      3
# 4447           6      1   42.466813      0.000334              1     14
# 2684           6      3   75.888156      0.000347              1     11
#
#       HouseFloor  HouseYear  Ecology_1  Social_1  ...  Social_3  Helthcare_2  \
# 7885          15       2011   0.319809        25  ...        16            5
# 5549          18       1969   0.000000        33  ...         1            2
# 4808           9       1974   0.150818        16  ...         4            4
# 4447          17       2014   0.243205         5  ...         0            0
# 2684          17       2014   0.243205         5  ...         0            0
#
#       Shops_1  Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 7885        8            0            1            0            1          0
# 5549        5            0            1            0            1          0
# 4808        5            0            1            0            1          0
# 4447        0            0            1            0            1          0
# 2684        0            0            1            0            1          0
#
#       Shops_2_B          Price
# 7885          1  289034.391871
# 5549          1  174548.966339
# 4808          1  258091.883679
# 4447          1  127196.762031
# 2684          1  218500.747041
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Стандартизация признаков

# %%
feature_names_for_stand = df[feature_names].select_dtypes(include=['float64', 'int64']).columns.tolist()
feature_names_for_stand
# Out:
# ['DistrictId',
#  'Rooms',
#  'Square',
#  'Square_Price',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Social_1',
#  'Social_2',
#  'Social_3',
#  'Helthcare_2',
#  'Shops_1']

# %%
# scaler = StandardScaler()
# stand_features = scaler.fit_transform(df[feature_names_for_stand])
stand_features = df

# %%
stand_features
# Out:
#       DistrictId  Rooms      Square  Square_Price  KitchenSquare  Floor  \
# 7885           0      1  109.144492      0.000378             15      6
# 5549           2      1   34.472263      0.000197              5      5
# 4808           5      3   57.607965      0.000223              5      3
# 4447           6      1   42.466813      0.000334              1     14
# 2684           6      3   75.888156      0.000347              1     11
# ...          ...    ...         ...           ...            ...    ...
# 2937          53      1   33.258974      0.000165              6      6
# 2457          29      2   45.280336      0.000189              5      8
# 659           46      1   33.013935      0.000196              6      4
# 4768          94      3   77.325275      0.000218             10      7
# 705           22      1   39.956966      0.000218              8      2
#
#       HouseFloor  HouseYear  Ecology_1  Social_1  ...  Social_3  Helthcare_2  \
# 7885          15       2011   0.319809        25  ...        16            5
# 5549          18       1969   0.000000        33  ...         1            2
# 4808           9       1974   0.150818        16  ...         4            4
# 4447          17       2014   0.243205         5  ...         0            0
# 2684          17       2014   0.243205         5  ...         0            0
# ...          ...        ...        ...       ...  ...       ...          ...
# 2937          12       1972   0.313925        22  ...        11            2
# 2457           8       1967   0.069660        31  ...         4            1
# 659            9       1987   0.188784        31  ...         4            0
# 4768          16       1982   0.282798        33  ...         2            0
# 705           17       1989   0.133215        49  ...         3            3
#
#       Shops_1  Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 7885        8            0            1            0            1          0
# 5549        5            0            1            0            1          0
# 4808        5            0            1            0            1          0
# 4447        0            0            1            0            1          0
# 2684        0            0            1            0            1          0
# ...       ...          ...          ...          ...          ...        ...
# 2937       10            0            1            0            1          0
# 2457        2            0            1            0            1          0
# 659         1            0            1            0            1          0
# 4768        6            0            1            0            1          0
# 705         4            0            1            0            1          1
#
#       Shops_2_B          Price
# 7885          1  289034.391871
# 5549          1  174548.966339
# 4808          1  258091.883679
# 4447          1  127196.762031
# 2684          1  218500.747041
# ...         ...            ...
# 2937          1  201307.933649
# 2457          1  239503.727371
# 659           1  168233.016477
# 4768          1  354690.491271
# 705           0  183467.407815
#
# [9991 rows x 21 columns]

# %%
df[feature_names_for_stand] = pd.DataFrame(stand_features, columns=feature_names_for_stand)

# %%
df.head()
# Out:
#       DistrictId  Rooms      Square  Square_Price  KitchenSquare  Floor  \
# 7885           0      1  109.144492      0.000378             15      6
# 5549           2      1   34.472263      0.000197              5      5
# 4808           5      3   57.607965      0.000223              5      3
# 4447           6      1   42.466813      0.000334              1     14
# 2684           6      3   75.888156      0.000347              1     11
#
#       HouseFloor  HouseYear  Ecology_1  Social_1  ...  Social_3  Helthcare_2  \
# 7885          15       2011   0.319809        25  ...        16            5
# 5549          18       1969   0.000000        33  ...         1            2
# 4808           9       1974   0.150818        16  ...         4            4
# 4447          17       2014   0.243205         5  ...         0            0
# 2684          17       2014   0.243205         5  ...         0            0
#
#       Shops_1  Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 7885        8            0            1            0            1          0
# 5549        5            0            1            0            1          0
# 4808        5            0            1            0            1          0
# 4447        0            0            1            0            1          0
# 2684        0            0            1            0            1          0
#
#       Shops_2_B          Price
# 7885          1  289034.391871
# 5549          1  174548.966339
# 4808          1  258091.883679
# 4447          1  127196.762031
# 2684          1  218500.747041
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Сохранение обучающего датасета

# %%
df.to_csv(TRAIN_DATASET_PATH_ADD, index=False, encoding='utf-8')

# %% [markdown]
# ### Разбиение на train и test

# %%
X = df[feature_names]
y = df[target_name]

# %%
len(X) - X.count()
# Out:
# DistrictId       0
# Rooms            0
# Square           0
# Square_Price     0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Social_1         0
# Social_2         0
# Social_3         0
# Helthcare_2      0
# Shops_1          0
# Ecology_2_A      0
# Ecology_2_B      0
# Ecology_3_A      0
# Ecology_3_B      0
# Shops_2_A        0
# Shops_2_B        0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=21)

# %% [markdown]
# ### Построение базовых моделей и выбор лучшей

# %% [markdown]
# **Linear Regression**

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_preds = lr_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
# Out:
# R2:	0.864
# MAE:	22320.823
# MSE:	1141596498.433

# %%
# sorted(y_train_preds)

# %%
y_test_preds = lr_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)
# Out:
# R2:	0.851
# MAE:	23425.686
# MSE:	1344390144.578

# %%
y_test_preds
# Out:
# array([208379.09922769, 262565.88509373, 241162.30688722, ...,
#        218930.52943799, 178997.80101011, 264501.34161178])

# %%
lasso_model = Lasso(alpha=0.3)
lasso_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.3, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_train_preds = lasso_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
# Out:
# R2:	0.863
# MAE:	22457.701
# MSE:	1150939717.624

# %%
y_test_preds = lasso_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)
# Out:
# R2:	0.847
# MAE:	23658.461
# MSE:	1381531173.714

# %%
ridge_model = Ridge(alpha=0.3)
ridge_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.3, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
y_train_preds = ridge_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
# Out:
# R2:	0.534
# MAE:	43492.148
# MSE:	3915823925.262

# %%
y_test_preds = lasso_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)
# Out:
# R2:	0.847
# MAE:	23658.461
# MSE:	1381531173.714

# %%
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_train_preds = rf_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
# Out:
# R2:	0.999
# MAE:	1234.384
# MSE:	9080522.095

# %%
y_test_preds = rf_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)
# Out:
# R2:	0.991
# MAE:	2931.583
# MSE:	80724317.195

# %%
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_train_preds = gb_model.predict(X_train)
evaluate_preds(y_train, y_train_preds)
# Out:
# R2:	0.997
# MAE:	3657.266
# MSE:	25372032.034

# %%
y_test_preds = gb_model.predict(X_test)
evaluate_preds(y_test, y_test_preds)
# Out:
# R2:	0.994
# MAE:	4483.72
# MSE:	57264447.05

# %%
X_train.dtypes
# Out:
# DistrictId         int64
# Rooms              int64
# Square           float64
# Square_Price     float64
# KitchenSquare      int64
# Floor              int64
# HouseFloor         int64
# HouseYear          int64
# Ecology_1        float64
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Helthcare_2        int64
# Shops_1            int64
# Ecology_2_A        uint8
# Ecology_2_B        uint8
# Ecology_3_A        uint8
# Ecology_3_B        uint8
# Shops_2_A          uint8
# Shops_2_B          uint8
# dtype: object

# %%
y_train.dtypes
# Out:
# dtype('float64')

# %%
# clf = LogisticRegression()
# clf.fit(training_data_X, training_scores_Y)

# lab_enc = preprocessing.LabelEncoder()
# y_train_encoded = lab_enc.fit_transform(y_train)

# clf = LogisticRegression()
# clf.fit(training_data_X, training_scores_encoded)

# %%
# log_r_model = LogisticRegression(solver="liblinear")
# log_r_model.fit(X_train, y_train_encoded)

# %%
# ? LogisticRegression

# %%
# y_train_preds = log_r_model.predict(X_train)
# evaluate_preds(y_train, y_train_preds)

# %%
# y_test_preds = log_r_model.predict(X_test)
# evaluate_preds(y_test, y_test_preds)

# %% [markdown]
# ## Загрузка тестового набора

# %%
test = pd.read_csv(TEST_DATASET_PATH)
test.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
# 3  15664          47    2.0  73.046609   51.940842            9.0     22
# 4  14275          27    1.0  47.527111   43.387569            1.0     17
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
# 3        22.0       2007   0.101872         B         B        23      4583
# 4        17.0       2017   0.072158         B         B         2       629
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         1           NaN            0        0       B
# 1         3           NaN            0        2       B
# 2        87        4702.0            5        5       B
# 3         3           NaN            3        3       B
# 4         1           NaN            0        0       A

# %%
test.shape
# Out:
# (5000, 19)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
# Id               5000 non-null int64
# DistrictId       5000 non-null int64
# Rooms            5000 non-null float64
# Square           5000 non-null float64
# LifeSquare       3959 non-null float64
# KitchenSquare    5000 non-null float64
# Floor            5000 non-null int64
# HouseFloor       5000 non-null float64
# HouseYear        5000 non-null int64
# Ecology_1        5000 non-null float64
# Ecology_2        5000 non-null object
# Ecology_3        5000 non-null object
# Social_1         5000 non-null int64
# Social_2         5000 non-null int64
# Social_3         5000 non-null int64
# Healthcare_1     2623 non-null float64
# Helthcare_2      5000 non-null int64
# Shops_1          5000 non-null int64
# Shops_2          5000 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 742.3+ KB

# %%
test.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# dtype: object

# %% [markdown]
# Количество комнат должно быть целым числом.

# %%
test['Rooms'].dtype
# Out:
# dtype('float64')

# %%
test['Rooms'] = test['Rooms'].astype('int64')

# %%
test['Rooms'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Количество этажей целочисленное значение.

# %%
test['HouseFloor'].dtype
# Out:
# dtype('float64')

# %%
test['HouseFloor'] = test['HouseFloor'].astype('int64')

# %%
test['HouseFloor'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Площадь кухни по факту есть целочисленное значение, что ни есть целочисленное значение, то есть выброс.

# %%
test['KitchenSquare'].dtype
# Out:
# dtype('float64')

# %%
test['KitchenSquare'] = test['KitchenSquare'].astype('int64')

# %%
test['KitchenSquare'].dtype
# Out:
# dtype('int64')

# %%
test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.449500    36.158810
# std     4832.674037    44.179466     0.838594    19.092787    17.825287
# min        1.000000     0.000000     0.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.000000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# min         0.000000     1.000000     0.000000  1908.000000     0.000000
# 25%         1.000000     4.000000     9.000000  1973.000000     0.019509
# 50%         6.000000     7.000000    12.000000  1977.000000     0.072158
# 75%         9.000000    12.000000    17.000000  2000.000000     0.195781
# max       620.000000    78.000000    99.000000  2020.000000     0.521867
#
#           Social_1      Social_2     Social_3  Healthcare_1  Helthcare_2  \
# count  5000.000000   5000.000000  5000.000000   2623.000000   5000.00000
# mean     24.933800   5406.900000     8.262600   1146.657263      1.31940
# std      17.532202   4026.614773    23.863762   1044.744231      1.47994
# min       0.000000    168.000000     0.000000      0.000000      0.00000
# 25%       6.000000   1564.000000     0.000000    325.000000      0.00000
# 50%      25.000000   5285.000000     2.000000    900.000000      1.00000
# 75%      36.000000   7287.000000     5.000000   1548.000000      2.00000
# max      74.000000  19083.000000   141.000000   4849.000000      6.00000
#
#            Shops_1
# count  5000.000000
# mean      4.242800
# std       4.777365
# min       0.000000
# 25%       1.000000
# 50%       3.000000
# 75%       6.000000
# max      23.000000

# %%
len(test) - test.count()
# Out:
# Id                  0
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       1041
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     2377
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# dtype: int64

# %% [markdown]
# **LifeSquare**

# %%
for room in test['Rooms'][test['LifeSquare'].isnull()].unique():
    for year in test['HouseYear'][test['LifeSquare'].isnull()].unique():
        for floor in test['HouseFloor'][test['LifeSquare'].isnull()].unique():
            test.loc[test['LifeSquare'].isnull() & (test['Rooms'] == room) & (test['HouseYear'] == year) & (test['HouseFloor'] == floor), 'LifeSquare'] = test['LifeSquare'][test['LifeSquare'].notnull() & (test['Rooms'] == room) & (test['HouseYear'] == year) & (test['HouseFloor'] == floor)].median()

# %%
test.loc[test['LifeSquare'].isnull()]
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 5     7633          53      1   40.675627         NaN              1     21
# 158   1755          52      1   39.098603         NaN             10      7
# 205   5060          53      2   55.825260         NaN              1      2
# 214   5896          62      1   41.274114         NaN             10      3
# 257   5399           1      3   88.011164         NaN             10     18
# ...    ...         ...    ...         ...         ...            ...    ...
# 4807  7130          30      1   46.263117         NaN              1     20
# 4828  5485          62      3   88.098883         NaN              1     14
# 4907  2024          27      3  108.650465         NaN              1      4
# 4922  2515          23      1   49.520325         NaN              1      4
# 4953  6533           1      2   64.919583         NaN             10     19
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 5             21       1977   0.049637         B         B        34
# 158           20       2016   0.371149         B         B        34
# 205           19       1977   0.049637         B         B        34
# 214            8       1977   0.072158         B         B         2
# 257           22       2016   0.007122         B         B         1
# ...          ...        ...        ...       ...       ...       ...
# 4807          22       2014   0.000078         B         B        22
# 4828          16       2015   0.072158         B         B         2
# 4907           6       1977   0.075424         B         B        11
# 4922          16       2016   0.014073         B         B         2
# 4953          22       2019   0.007122         B         B         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 5         7759         0         229.0            1        3       B
# 158       7065         1         750.0            2        5       B
# 205       7759         0         229.0            1        3       B
# 214        629         1           NaN            0        0       A
# 257        264         0           NaN            0        1       B
# ...        ...       ...           ...          ...      ...     ...
# 4807      6398       141        1046.0            3       23       B
# 4828       629         1           NaN            0        0       A
# 4907      3097         0           NaN            0        0       B
# 4922       475         0           NaN            0        0       B
# 4953       264         0           NaN            0        1       B
#
# [62 rows x 19 columns]

# %%
for room in test['Rooms'][test['LifeSquare'].isnull()].unique():
    for year in test['HouseYear'][test['LifeSquare'].isnull()].unique():
        test.loc[test['LifeSquare'].isnull() & (test['Rooms'] == room) & (test['HouseYear'] == year), 'LifeSquare'] = test['LifeSquare'][test['LifeSquare'].notnull() & (test['Rooms'] == room) & (test['HouseYear'] == year)].median()

# %%
test.loc[test['LifeSquare'].isnull()]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2071  10793          23      6  110.750226         NaN              0      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2071           2       2015   0.014073         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 2071       475         0           NaN            0        0       B

# %%
test.loc[test['LifeSquare'].isnull(), 'LifeSquare'] = test['LifeSquare'][test['LifeSquare'].notnull()].median()

# %%
test.loc[test['LifeSquare'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %% [markdown]
# **Healthcare_1**

# %% [markdown]
# "Раскидаем" пустые значения по имеющимся классам значений

# %% [markdown]
# Получим уникальные значения из выборки

# %%
values = list(test.loc[test['Healthcare_1'].notnull(), 'Healthcare_1'].unique())

# %%
values = sorted(values)

# %%
length = len(values)

# %%
length
# Out:
# 79

# %%
values[:5]
# Out:
# [0.0, 30.0, 32.0, 35.0, 46.0]

# %%
values[length - 5:]
# Out:
# [4087.0, 4129.0, 4508.0, 4702.0, 4849.0]

# %%
b = test.loc[test['Healthcare_1'].isnull()]

# %%
for id in b['Id']:
    test.loc[test['Id'] == id, 'Healthcare_1'] = values[random.randint(0, length - 1)]

# %%
test.loc[test['Healthcare_1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %% [markdown]
# **Распределение по комнатам (Rooms)**

# %%
test['Rooms'].unique()
# Out:
# array([ 2,  1,  3,  4,  5,  6,  0, 17], dtype=int64)

# %% [markdown]
# 6,  0, 17 - лишнее

# %%
test.loc[test['Rooms'] == 0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2406   3343          58      0  116.824201  113.692424              0      3
# 2524  10729          27      0   76.345154   42.820796             12     14
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2406           3       1977   0.437885         B         B        23
# 2524           0       1977   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 2406      5735         3        1084.0            0        5       B
# 2524       469         0        1183.0            0        0       B

# %%
test.loc[test['Rooms'] == 6]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2071  10793          23      6  110.750226   35.310002              0      2
# 3217   4058          27      6  223.453689  104.113552             16      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2071           2       2015   0.014073         B         B         2
# 3217           2       2017   0.041116         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 2071       475         0         100.0            0        0       B
# 3217     14892         4        2620.0            1        4       B

# %%
test.loc[test['Rooms'] == 17]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3398  1435         111     17  52.866107   32.528342              8     15
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3398          17       1987   0.093443         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 3398      4635         5        3300.0            2        4       B

# %%
test.loc[test['Id'] == 3343, 'Rooms'] = 5

# %%
test.loc[test['Id'] == 10729, 'Rooms'] = 3

# %%
test.loc[test['Id'] == 10793, 'Rooms'] = 5

# %%
test.loc[test['Id'] == 4058, 'Rooms'] = 5

# %%
test.loc[test['Id'] == 1435, 'Rooms'] = 1

# %% [markdown]
# **Общая площадь квартиры (Square)**

# %%
test.sort_values(by="Square", inplace=True)

# %%
test
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 66     9011          53      1    1.378543    1.353573              1      1
# 4902   1420          45      1    1.975769    2.900371              1      1
# 4490   1165          27      1    2.372101    1.899119              1      2
# 608   16401          30      1    2.645046    4.338755              1      2
# 4713    170           6      2    2.900586   61.468563              1     18
# ...     ...         ...    ...         ...         ...            ...    ...
# 2039   3357          27      3  170.476326   75.973612              8      2
# 1264  13589          27      3  173.974480   76.289475              9      3
# 1499   7769         124      4  189.679576  114.708673              4     19
# 3909   1397          76      3  221.138768  118.055342              4     32
# 3217   4058          27      5  223.453689  104.113552             16      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 66             1       1977   0.049637         B         B        34
# 4902           1       1977   0.195781         B         B        23
# 4490          17       1977   0.011654         B         B         4
# 608            1       1977   0.000078         B         B        22
# 4713          17       2014   0.243205         B         B         5
# ...          ...        ...        ...       ...       ...       ...
# 2039           2       2017   0.041116         B         B        53
# 1264           3       2017   0.041116         B         B        53
# 1499          40       2013   0.174739         B         B        17
# 3909          48       2011   0.000000         B         B         7
# 3217           2       2017   0.041116         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 66        7759         0         229.0            1        3       B
# 4902      5212         6        1084.0            3        2       B
# 4490       915         0        1940.0            0        0       B
# 608       6398       141        1046.0            3       23       B
# 4713      1564         0         540.0            0        0       B
# ...        ...       ...           ...          ...      ...     ...
# 2039     14892         4        3300.0            1        4       B
# 1264     14892         4         100.0            1        4       B
# 1499      3379         9         100.0            0        3       B
# 3909      1660        39        1786.0            1        5       B
# 3217     14892         4        2620.0            1        4       B
#
# [5000 rows x 19 columns]

# %% [markdown]
# **Жилая площадь (LifeSquare)**

# %%
test.sort_values(by="LifeSquare", inplace=True)

# %%
test
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 78     6553          34      5  122.375273    0.333490              0      9
# 2992   6406          27      2   66.469510    0.567267              0      4
# 2341   3028           9      1   43.348348    0.809265              0     16
# 2398  13014          53      3   81.141636    0.863989              0     10
# 326   14959           1      2   64.112441    1.181139              1     13
# ...     ...         ...    ...         ...         ...            ...    ...
# 2115   2198          54      3  125.401265  128.913470              1      7
# 2126  16531          93      3  136.389391  136.689191              0      1
# 2081   1686          62      3  137.653211  136.921090              0      4
# 2557  16053          17      4  168.729035  169.901701              0      4
# 410   11533          94      2   48.713443  303.071094              6      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 78             0       1977   0.069753         B         B        53
# 2992           0       2018   0.017647         B         B         2
# 2341          17       2015   0.161532         B         B        25
# 2398           1       2017   0.049637         B         B        34
# 326           17       1977   0.007122         B         B         1
# ...          ...        ...        ...       ...       ...       ...
# 2115           1       2016   0.006076         B         B        30
# 2126           1       1977   0.004949         B         B         0
# 2081           3       1977   0.072158         B         B         2
# 2557           0       2013   0.093443         B         B        23
# 410           12       1974   0.521867         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 78       13670         4        1994.0            1       11       B
# 2992       469         0         800.0            0        0       B
# 2341      5648         1          30.0            2        4       B
# 2398      7759         0         229.0            1        3       B
# 326        264         0        2643.0            0        1       B
# ...        ...       ...           ...          ...      ...     ...
# 2115      5285         0         645.0            6        6       B
# 2126       186         0        1815.0            0        0       B
# 2081       629         1        1308.0            0        0       A
# 2557      4635         5        3300.0            2        4       B
# 410       6149         0         229.0            0        0       B
#
# [5000 rows x 19 columns]

# %%
test.loc[test['Id'] == 11533, 'LifeSquare'] = 30

# %% [markdown]
# **Кухня (KitchenSquare)**

# %%
test.sort_values(by="KitchenSquare", inplace=True)

# %%
test
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 78     6553          34      5  122.375273    0.333490              0      9
# 3672   1474          74      1   48.031878   41.832877              0      7
# 2827   4659          74      1   52.103243   41.832877              0      8
# 4564    211          27      1   44.783510   41.832877              0      5
# 4460   9535           1      1   48.460912   41.832877              0     13
# ...     ...         ...    ...         ...         ...            ...    ...
# 4281   8015          27      1   66.099096   33.639611             62      3
# 1456   5260          73      3   69.358242   51.247581             65      6
# 4555  12640           6      2   54.629142   31.486308             97      4
# 1777   3341          62      3  112.114019  112.247841            112      3
# 1964  14594          11      2   42.795304   24.223770            620     11
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 78             0       1977   0.069753         B         B        53
# 3672           0       1977   0.075779         B         B         6
# 2827           0       1977   0.075779         B         B         6
# 4564           0       1977   0.072158         B         B         2
# 4460           0       1977   0.007122         B         B         1
# ...          ...        ...        ...       ...       ...       ...
# 4281           7       2016   0.014058         B         B         1
# 1456           6       1931   0.042032         B         B        37
# 4555          17       2015   0.243205         B         B         5
# 1777           3       2017   0.072158         B         B         2
# 1964          14       1972   0.038693         B         B        28
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 78       13670         4        1994.0            1       11       B
# 3672      1437         3        2729.0            0        2       B
# 2827      1437         3         262.0            0        2       B
# 4564       629         1        2301.0            0        0       A
# 4460       264         0        1994.0            0        1       B
# ...        ...       ...           ...          ...      ...     ...
# 4281       290         0        1020.0            0        0       B
# 1456      6856        84        1940.0            2        5       B
# 4555      1564         0         540.0            0        0       B
# 1777       629         1         620.0            0        0       A
# 1964      6533         1        1015.0            2        5       B
#
# [5000 rows x 19 columns]

# %%
id_list = list(test.loc[test['KitchenSquare'] > 25, 'Id'])

# %%
for id in id_list:
    rooms = list(test['Rooms'][test['Id'] == id])[0]
    floor = list(test['HouseFloor'][test['Id'] == id])[0]
    result = test['KitchenSquare'][(test['Rooms'] == rooms) & (test['HouseFloor'] == floor) & (test['HouseYear'] != 1977)].median()
    if pd.notnull(result):
        test.loc[test['Id'] == id, 'KitchenSquare'] = round(result,0)

# %%
test
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 78     6553          34      5  122.375273    0.333490            0.0      9
# 3672   1474          74      1   48.031878   41.832877            0.0      7
# 2827   4659          74      1   52.103243   41.832877            0.0      8
# 4564    211          27      1   44.783510   41.832877            0.0      5
# 4460   9535           1      1   48.460912   41.832877            0.0     13
# ...     ...         ...    ...         ...         ...            ...    ...
# 4281   8015          27      1   66.099096   33.639611            9.0      3
# 1456   5260          73      3   69.358242   51.247581            8.0      6
# 4555  12640           6      2   54.629142   31.486308            9.0      4
# 1777   3341          62      3  112.114019  112.247841            3.0      3
# 1964  14594          11      2   42.795304   24.223770            8.0     11
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 78             0       1977   0.069753         B         B        53
# 3672           0       1977   0.075779         B         B         6
# 2827           0       1977   0.075779         B         B         6
# 4564           0       1977   0.072158         B         B         2
# 4460           0       1977   0.007122         B         B         1
# ...          ...        ...        ...       ...       ...       ...
# 4281           7       2016   0.014058         B         B         1
# 1456           6       1931   0.042032         B         B        37
# 4555          17       2015   0.243205         B         B         5
# 1777           3       2017   0.072158         B         B         2
# 1964          14       1972   0.038693         B         B        28
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 78       13670         4        1994.0            1       11       B
# 3672      1437         3        2729.0            0        2       B
# 2827      1437         3         262.0            0        2       B
# 4564       629         1        2301.0            0        0       A
# 4460       264         0        1994.0            0        1       B
# ...        ...       ...           ...          ...      ...     ...
# 4281       290         0        1020.0            0        0       B
# 1456      6856        84        1940.0            2        5       B
# 4555      1564         0         540.0            0        0       B
# 1777       629         1         620.0            0        0       A
# 1964      6533         1        1015.0            2        5       B
#
# [5000 rows x 19 columns]

# %% [markdown]
# **Этаж (Floor)**

# %%
test.sort_values(by="Floor", inplace=True)

# %%
test
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1857   6611          99      2   44.594325   31.894068            5.0      1
# 2219  10148          69      2   53.807445   30.943436            7.0      1
# 1646  12374          84      3   80.510899   53.211190            8.0      1
# 2286  11491          54      1   78.181873   75.203901            1.0      1
# 3523  16444          31      1   32.731195   15.019807            8.0      1
# ...     ...         ...    ...         ...         ...            ...    ...
# 3585   4533          31      2   83.963299   38.419224           14.0     33
# 4764   2461          72      2  103.114357    4.312838            1.0     34
# 1587   5707          76      2   73.363523   38.740060            5.0     38
# 3711    414          76      2   67.609808   41.175948            5.0     46
# 4698  15759          17      2   57.601870   37.744743           10.0     78
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1857           9       1969   0.033494         B         B        66
# 2219           9       1972   0.000991         B         B        33
# 1646           5       1953   0.149666         B         B        22
# 2286          15       2017   0.006076         B         B        30
# 3523           5       1964   0.151346         B         A        32
# ...          ...        ...        ...       ...       ...       ...
# 3585          40       2014   0.151346         B         A        32
# 4764          37       2015   0.210473         B         B        11
# 1587          48       2010   0.000000         B         B         7
# 3711          48       2002   0.000000         B         B         7
# 4698          22       1989   0.000000         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1857     10573         1        1322.0            3        8       B
# 2219      6783         3         705.0            1        9       B
# 1646      4789         2        4087.0            4        1       B
# 2286      5285         0         645.0            6        6       B
# 3523      5889        10         830.0            4        1       B
# ...        ...       ...           ...          ...      ...     ...
# 3585      5889        10         830.0            4        1       B
# 4764      2398         2        1994.0            3        0       B
# 1587      1660        39        1786.0            1        5       B
# 3711      1660        39        1786.0            1        5       B
# 4698      5027         4          46.0            1        1       B
#
# [5000 rows x 19 columns]

# %%
test.loc[test['Id'] == 15759, 'Floor'] = 78

# %% [markdown]
# **Этажность дома (HouseFloor)**

# %%
test.sort_values(by="HouseFloor", inplace=True)

# %%
test
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 4664   1736          27      1   51.492952   41.832877            0.0      5
# 2425  12512          27      1   40.950673   41.832877            0.0      2
# 772     902          27      3   99.293191   86.540359            0.0      2
# 4798    208          62      2   76.048201   60.727617            0.0      2
# 113    5032          30      1   50.738045   41.832877            0.0      5
# ...     ...         ...    ...         ...         ...            ...    ...
# 1499   7769         124      4  189.679576  114.708673            4.0     19
# 3909   1397          76      3  221.138768  118.055342            4.0     32
# 1587   5707          76      2   73.363523   38.740060            5.0     38
# 3711    414          76      2   67.609808   41.175948            5.0     46
# 651   15864          27      3   47.722835   47.098813            9.0     18
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4664           0       1977   0.072158         B         B         2
# 2425           0       1977   0.017647         B         B         2
# 772            0       1977   0.075424         B         B        11
# 4798           0       1977   0.072158         B         B         2
# 113            0       1977   0.000078         B         B        22
# ...          ...        ...        ...       ...       ...       ...
# 1499          40       2013   0.174739         B         B        17
# 3909          48       2011   0.000000         B         B         7
# 1587          48       2010   0.000000         B         B         7
# 3711          48       2002   0.000000         B         B         7
# 651           99       1977   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4664       629         1        1430.0            0        0       A
# 2425       469         0        1046.0            0        0       B
# 772       3097         0         192.0            0        0       B
# 4798       629         1         176.0            0        0       A
# 113       6398       141        1046.0            3       23       B
# ...        ...       ...           ...          ...      ...     ...
# 1499      3379         9         100.0            0        3       B
# 3909      1660        39        1786.0            1        5       B
# 1587      1660        39        1786.0            1        5       B
# 3711      1660        39        1786.0            1        5       B
# 651        629         1        2500.0            0        0       A
#
# [5000 rows x 19 columns]

# %%
test.loc[test['Id'] == 15864, 'HouseFloor'] = 18

# %% [markdown]
# **Год постройки (HouseYear)**

# %%
test.sort_values(by="HouseYear", inplace=True)

# %%
test
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 3253  12316         183      5  157.976101  101.040485           12.0      7
# 2      5480         190      1   13.597819   15.948246           12.0      2
# 2691   9076          60      3   61.400464   38.591813            8.0      5
# 64     3726         161      1   52.708494   20.502345           11.0      3
# 1475  16217         206      4   76.428426   50.344903           11.0      7
# ...     ...         ...    ...         ...         ...            ...    ...
# 3382    651          53      1   40.108538   21.984746            8.0     12
# 888    8560          37      2   57.979074   41.758328           10.0      7
# 4273   8311          53      1   38.747897   21.602020            8.0     15
# 4777  16098          62      2   64.481854   36.653054            9.0     12
# 3255   9398          58      2   70.999008   42.275945           17.0     13
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3253           8       1908   0.246624         B         B        14
# 2              5       1909   0.000000         B         B        30
# 2691           5       1910   0.341072         B         B        27
# 64             7       1911   0.014423         B         B        19
# 1475           6       1912   0.042032         B         B        37
# ...          ...        ...        ...       ...       ...       ...
# 3382          24       2020   0.049637         B         B        34
# 888           20       2020   0.178917         B         B        18
# 4273          24       2020   0.049637         B         B        34
# 4777          14       2020   0.072158         B         B         2
# 3255          15       2020   0.437885         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 3253      2940        45         705.0            3        6       B
# 2         7538        87        4702.0            5        5       B
# 2691      5664        48        2300.0            3       11       B
# 64        3806         4        1970.0            0        3       B
# 1475      6856        84        1940.0            2        5       B
# ...        ...       ...           ...          ...      ...     ...
# 3382      7759         0         229.0            1        3       B
# 888       3594         4         192.0            1        5       B
# 4273      7759         0         229.0            1        3       B
# 4777       629         1        4508.0            0        0       A
# 3255      5735         3        1084.0            0        5       B
#
# [5000 rows x 19 columns]

# %% [markdown]
# ### Отбор и построение новых признаков

# %%
id_list = list(test.loc[test['Id'].notnull(), 'Id'])

# %%
for id in id_list:
    district = list(test['DistrictId'][test['Id'] == id])[0]
    rooms = list(test['Rooms'][test['Id'] == id])[0]
    floor = list(test['HouseFloor'][test['Id'] == id])[0]
    result = train_add['Square_Price'][(train_add['DistrictId'] == district) & (train_add['Rooms'] == rooms) & (train_add['HouseFloor'] == floor) & (test['HouseYear'] != 1977)].median()
    if pd.notnull(result):
        test.loc[test['Id'] == id, 'Square_Price'] = result

# %%
len(test) - test.count()
# Out:
# Id                  0
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare          0
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1        0
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# Square_Price     1463
# dtype: int64

# %%
id_list = list(test.loc[test['Square_Price'].isnull(), 'Id'])

# %%
for id in id_list:
    district = list(test['DistrictId'][test['Id'] == id])[0]
    rooms = list(test['Rooms'][test['Id'] == id])[0]
    result = train_add['Square_Price'][(train_add['DistrictId'] == district) & (train_add['Rooms'] == rooms) & (test['HouseYear'] != 1977)].median()
    if pd.notnull(result):
        test.loc[test['Id'] == id, 'Square_Price'] = result

# %%
len(test) - test.count()
# Out:
# Id                 0
# DistrictId         0
# Rooms              0
# Square             0
# LifeSquare         0
# KitchenSquare      0
# Floor              0
# HouseFloor         0
# HouseYear          0
# Ecology_1          0
# Ecology_2          0
# Ecology_3          0
# Social_1           0
# Social_2           0
# Social_3           0
# Healthcare_1       0
# Helthcare_2        0
# Shops_1            0
# Shops_2            0
# Square_Price     183
# dtype: int64

# %%
id_list = list(test.loc[test['Square_Price'].isnull(), 'Id'])

# %%
for id in id_list:
    rooms = list(test['Rooms'][test['Id'] == id])[0]
    result = train_add['Square_Price'][(train_add['Rooms'] == rooms) & (test['HouseYear'] != 1977)].median()
    if pd.notnull(result):
        test.loc[test['Id'] == id, 'Square_Price'] = result

# %%
len(test) - test.count()
# Out:
# Id               0
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# Square_Price     0
# dtype: int64

# %%
test.sort_values(by="Id", inplace=True)

# %%
test = pd.concat([test, pd.get_dummies(test['Ecology_2'], prefix='Ecology_2')], axis=1)

# %%
test = pd.concat([test, pd.get_dummies(test['Ecology_3'], prefix='Ecology_3')], axis=1)

# %%
test = pd.concat([test, pd.get_dummies(test['Shops_2'], prefix='Shops_2')], axis=1)

# %%
test.drop(['Ecology_2'],axis=1,inplace=True)

# %%
test.drop(['Ecology_3'],axis=1,inplace=True)

# %%
test.drop(['Shops_2'],axis=1,inplace=True)

# %%
test.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4422   1           1      2  83.061098   83.830248            0.0     10
# 979    3           3      1  30.185483   14.810573            6.0      4
# 4157   4           4      1  37.294669   17.165597            8.0      9
# 712    8           8      3  83.930342   50.049315            8.0      4
# 4394   9           6      1  38.800420   42.560690            1.0      3
#
#       HouseFloor  HouseYear  Ecology_1  ...  Healthcare_1  Helthcare_2  \
# 4422          22       1977   0.007122  ...         262.0            0
# 979            9       1970   0.265089  ...        1937.0            3
# 4157           9       1970   0.327018  ...        2500.0            1
# 712           12       2007   0.092291  ...         165.0            1
# 4394          17       2017   0.243205  ...         540.0            0
#
#       Shops_1  Square_Price  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 4422        1      0.000307            0            1            0
# 979         2      0.000218            0            1            0
# 4157        0      0.000260            0            1            0
# 712         2      0.000254            0            1            0
# 4394        0      0.000334            0            1            0
#
#       Ecology_3_B  Shops_2_A  Shops_2_B
# 4422            1          0          1
# 979             1          0          1
# 4157            1          0          1
# 712             1          0          1
# 4394            1          0          1
#
# [5 rows x 23 columns]

# %%
df_test = test[feature_names]
df_test.head()
# Out:
#       DistrictId  Rooms     Square  Square_Price  KitchenSquare  Floor  \
# 4422           1      2  83.061098      0.000307            0.0     10
# 979            3      1  30.185483      0.000218            6.0      4
# 4157           4      1  37.294669      0.000260            8.0      9
# 712            8      3  83.930342      0.000254            8.0      4
# 4394           6      1  38.800420      0.000334            1.0      3
#
#       HouseFloor  HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# 4422          22       1977   0.007122         1       264         0
# 979            9       1970   0.265089        37      5288         0
# 4157           9       1970   0.327018        12      2270        23
# 712           12       2007   0.092291        21      4346         2
# 4394          17       2017   0.243205         5      1564         0
#
#       Helthcare_2  Shops_1  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 4422            0        1            0            1            0
# 979             3        2            0            1            0
# 4157            1        0            0            1            0
# 712             1        2            0            1            0
# 4394            0        0            0            1            0
#
#       Ecology_3_B  Shops_2_A  Shops_2_B
# 4422            1          0          1
# 979             1          0          1
# 4157            1          0          1
# 712             1          0          1
# 4394            1          0          1

# %%
feature_names_for_stand = df_test[feature_names].select_dtypes(include=['float64', 'int64']).columns.tolist()
feature_names_for_stand
# Out:
# ['DistrictId',
#  'Rooms',
#  'Square',
#  'Square_Price',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Social_1',
#  'Social_2',
#  'Social_3',
#  'Helthcare_2',
#  'Shops_1']

# %%
# stand_features_test = scaler.fit_transform(df_test[feature_names_for_stand])
stand_features_test = df_test

# %%
stand_features_test
# Out:
#       DistrictId  Rooms     Square  Square_Price  KitchenSquare  Floor  \
# 4422           1      2  83.061098      0.000307            0.0     10
# 979            3      1  30.185483      0.000218            6.0      4
# 4157           4      1  37.294669      0.000260            8.0      9
# 712            8      3  83.930342      0.000254            8.0      4
# 4394           6      1  38.800420      0.000334            1.0      3
# ...          ...    ...        ...           ...            ...    ...
# 2178          55      3  78.688848      0.000246            8.0     12
# 4355          74      1  48.763155      0.000331            1.0      7
# 4897         128      2  56.856093      0.000210            8.0      9
# 1908          26      1  36.802779      0.000213            5.0      4
# 4141           3      2  42.366967      0.000280            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# 4422          22       1977   0.007122         1       264         0
# 979            9       1970   0.265089        37      5288         0
# 4157           9       1970   0.327018        12      2270        23
# 712           12       2007   0.092291        21      4346         2
# 4394          17       2017   0.243205         5      1564         0
# ...          ...        ...        ...       ...       ...       ...
# 2178          14       1989   0.041365        31      5569         0
# 4355          10       2015   0.075779         6      1437         3
# 4897          14       1998   0.041116        53     14892         4
# 1908           9       1966   0.000000        36      6714         2
# 4141           5       1968   0.265089        37      5288         0
#
#       Helthcare_2  Shops_1  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 4422            0        1            0            1            0
# 979             3        2            0            1            0
# 4157            1        0            0            1            0
# 712             1        2            0            1            0
# 4394            0        0            0            1            0
# ...           ...      ...          ...          ...          ...
# 2178            1        4            0            1            0
# 4355            0        2            0            1            0
# 4897            1        4            0            1            0
# 1908            0        2            0            1            0
# 4141            3        2            0            1            0
#
#       Ecology_3_B  Shops_2_A  Shops_2_B
# 4422            1          0          1
# 979             1          0          1
# 4157            1          0          1
# 712             1          0          1
# 4394            1          0          1
# ...           ...        ...        ...
# 2178            1          0          1
# 4355            1          0          1
# 4897            1          0          1
# 1908            1          0          1
# 4141            1          0          1
#
# [5000 rows x 20 columns]

# %%
df_test[feature_names_for_stand] = pd.DataFrame(stand_features_test, columns=feature_names_for_stand)

# %%
df_test
# Out:
#       DistrictId  Rooms     Square  Square_Price  KitchenSquare  Floor  \
# 4422           1      2  83.061098      0.000307            0.0     10
# 979            3      1  30.185483      0.000218            6.0      4
# 4157           4      1  37.294669      0.000260            8.0      9
# 712            8      3  83.930342      0.000254            8.0      4
# 4394           6      1  38.800420      0.000334            1.0      3
# ...          ...    ...        ...           ...            ...    ...
# 2178          55      3  78.688848      0.000246            8.0     12
# 4355          74      1  48.763155      0.000331            1.0      7
# 4897         128      2  56.856093      0.000210            8.0      9
# 1908          26      1  36.802779      0.000213            5.0      4
# 4141           3      2  42.366967      0.000280            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# 4422          22       1977   0.007122         1       264         0
# 979            9       1970   0.265089        37      5288         0
# 4157           9       1970   0.327018        12      2270        23
# 712           12       2007   0.092291        21      4346         2
# 4394          17       2017   0.243205         5      1564         0
# ...          ...        ...        ...       ...       ...       ...
# 2178          14       1989   0.041365        31      5569         0
# 4355          10       2015   0.075779         6      1437         3
# 4897          14       1998   0.041116        53     14892         4
# 1908           9       1966   0.000000        36      6714         2
# 4141           5       1968   0.265089        37      5288         0
#
#       Helthcare_2  Shops_1  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 4422            0        1            0            1            0
# 979             3        2            0            1            0
# 4157            1        0            0            1            0
# 712             1        2            0            1            0
# 4394            0        0            0            1            0
# ...           ...      ...          ...          ...          ...
# 2178            1        4            0            1            0
# 4355            0        2            0            1            0
# 4897            1        4            0            1            0
# 1908            0        2            0            1            0
# 4141            3        2            0            1            0
#
#       Ecology_3_B  Shops_2_A  Shops_2_B
# 4422            1          0          1
# 979             1          0          1
# 4157            1          0          1
# 712             1          0          1
# 4394            1          0          1
# ...           ...        ...        ...
# 2178            1          0          1
# 4355            1          0          1
# 4897            1          0          1
# 1908            1          0          1
# 4141            1          0          1
#
# [5000 rows x 20 columns]

# %%
X_test = df_test[feature_names]

# %%
y_test_preds = rf_model.predict(X_test)

# %%
y_test_preds
# Out:
# array([269927.92854037, 143608.89940399, 141997.27549341, ...,
#        274219.88474389, 171334.75725288, 151795.6309722 ])

# %%
df_res = pd.DataFrame({'Id':list(test['Id']),'Price':list(y_test_preds)})

# %%
df_res.to_csv(DF_TEST_RESULT_DATASET_PATH, index=False, encoding='utf-8')
